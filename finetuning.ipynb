# %%
import os
import openai
openai.api_key = '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'
openai.File.create(
  file=open("fivek.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-trem4z5FNl9uNm6Rd7ck9d32 at 0x7fb57814d720> JSON: {
#   "object": "file",
#   "id": "file-trem4z5FNl9uNm6Rd7ck9d32",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 9339271,
#   "created_at": 1699574458,
#   "status": "processed",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-trem4z5FNl9uNm6Rd7ck9d32", model="gpt-3.5-turbo")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-a4jias763ql5oSCE7VwWGR3f at 0x7fb588e18ea0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-a4jias763ql5oSCE7VwWGR3f",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1699574557,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-1ziDaNp5PlVV7fXgyavNr6hY",
#   "result_files": [],
#   "status": "validating_files",
#   "validation_file": null,
#   "training_file": "file-trem4z5FNl9uNm6Rd7ck9d32",
#   "hyperparameters": {
#     "n_epochs": "auto",
#     "batch_size": "auto",
#     "learning_rate_multiplier": "auto"
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
openai.FineTuningJob.retrieve("ftjob-a4jias763ql5oSCE7VwWGR3f")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-a4jias763ql5oSCE7VwWGR3f at 0x7fb598f7c0e0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-a4jias763ql5oSCE7VwWGR3f",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1699574557,
#   "finished_at": 1699577327,
#   "fine_tuned_model": "ft:gpt-3.5-turbo-0613:personal::8J9zUcOA",
#   "organization_id": "org-1ziDaNp5PlVV7fXgyavNr6hY",
#   "result_files": [
#     "file-nsQJJxoBk6VRBsCqOWkYRKG1"
#   ],
#   "status": "succeeded",
#   "validation_file": null,
#   "training_file": "file-trem4z5FNl9uNm6Rd7ck9d32",
#   "hyperparameters": {
#     "n_epochs": 3,
#     "batch_size": 9,
#     "learning_rate_multiplier": 2
#   },
#   "trained_tokens": 5617362,
#   "error": null
# }

# %%
completion = openai.ChatCompletion.create(
  model="ft:gpt-3.5-turbo-0613:personal::8J9zUcOA",
  messages=[
    {"role": "system", "content": "You are a writer that writes in Wallace David Foster's style. Given a prompt you reproduce a paragraph of text (between 100 and 250 words) that mimics his style."},
    {"role": "user", "content": "Prompt: Write a scene in which characters engage in humorous and playful behavior while waiting for something, incorporating the use of specific props and physical actions."}
  ]
)
print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /var/folders/ql/480bqgd56wz4x3b25hcy0bhr0000gn/T/ipykernel_62516/3815421821.py in <module>
# ----> 1 completion = openai.ChatCompletion.create(
#       2   model="ft:gpt-3.5-turbo-0613:personal::8J9zUcOA",
#       3   messages=[
#       4     {"role": "system", "content": "You are a writer that writes in Wallace David Foster's style. Given a prompt you reproduce a paragraph of text (between 100 and 250 words) that mimics his style."},
#       5     {"role": "user", "content": "Prompt: Write a scene in which characters engage in humorous and playful behavior while waiting for something, incorporating the use of specific props and physical actions."}
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
# ...

# %%
completion = openai.ChatCompletion.create(
  model="ft:gpt-3.5-turbo-0613:personal::8GNAd2N8",
  messages=[
    {"role": "system", "content": "You are a writer that writes in Wallace David Foster's style. Given a prompt you reproduce a paragraph of text (between 100 and 250 words) that mimics his style."},
    {"role": "user", "content": "Prompt: Write a descriptive passage that conveys a character's frustration and anger towards another character, using vivid imagery and references to historical figures, while also exploring the character's philosophical perspective on a similar experience."}
  ]
)
print(completion.choices[0].message)

# %%
import os
import openai
openai.api_key = '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'
content = openai.File.download("file-oh52PInRhdOwzTPVdAs7bXxN")

content
# Out:
# b'step,train_loss,train_accuracy,valid_loss,valid_mean_token_accuracy\n1,0.6417,0.93333,,\n2,0.50569,0.93939,,\n3,0.54191,0.90909,,\n4,0.78331,0.84615,,\n5,0.63421,0.91429,,\n6,0.55963,0.94118,,\n7,0.71059,0.84211,,\n8,0.74322,0.83784,,\n9,0.62541,0.84483,,\n10,0.85614,0.78571,,\n11,0.55602,0.86486,,\n12,0.52661,0.90769,,\n13,0.58776,0.85106,,\n14,0.7724,0.78571,,\n15,0.70447,0.83333,,\n16,0.62947,0.81818,,\n17,0.42578,0.97059,,\n18,0.62672,0.93939,,\n19,0.66892,0.8,,\n20,0.5539,0.84848,,\n21,0.53548,0.87719,,\n22,0.59497,0.84906,,\n23,0.54825,0.86047,,\n24,0.44511,0.84706,,\n25,0.64999,0.86,,\n26,0.44217,0.91753,,\n27,0.39049,0.86567,,\n28,0.68042,0.81481,,\n29,0.56734,0.84375,,\n30,0.52708,0.85246,,\n31,0.57683,0.85965,,\n32,0.36793,0.95833,,\n33,0.42772,0.86842,,\n34,0.53179,0.86747,,\n35,0.43808,0.86275,,\n36,0.41519,0.86567,,\n37,0.51392,0.825,,\n38,0.37182,0.92063,,\n39,0.50105,0.875,,\n40,0.55667,0.86364,,\n41,0.46333,0.85106,,\n42,0.35587,0.93651,,\n43,0.44536,0.86885,,\n44,0
# ...
